# %%
import numpy as np
import numpy.random as rn
import matplotlib.pyplot as plt
import seaborn as sns
from btd import BTD

# %%
data = np.load('../dat/methylation/breast_and_ovarian/data.npz')

# %%
Beta_IJ = data['Beta_IJ']             # IxJ matrix of beta-values
sample_labels = data['sample_labels'] # I-length list of labels for each sample
locus_labels = data['locus_labels']   # J-length list of labels for each locus

# %%
(I, J) = Beta_IJ.shape
assert len(sample_labels) == I
assert len(locus_labels) == J
print I, J
# Out:
# 200 5000

# %%
C = 6          # number of sample clusters
K = 8          # number of locus clusters

b = 1.           # shape of background fluoresence noise
e = 0.1          # shape parameter for prior over factor matrices
f = 1.           # rate parameter for prior over factor matrices
eta = 0.1        # shape parameter for prior over core matrix
gam = 30         # prior rate of CpG dinucleotides in each locus
seed = 111111    # random seed (optional)
dirichlet = True # use Dirichlet priors (use them)

model = BTD(I=I, J=J, C=C, K=K, b=b, e=e, f=f, eta=eta, gam=gam, dirichlet=dirichlet, seed=seed)

# %%
num_itns = 500            # number of Gibbs sampling iterations to run
verbose = True            # whether to printout every iteration
initialize = True         # whether to randomly initialize parameters; initialization runs for 40 iterations

burnin = {'c_I': np.inf}  # dictionary where keys are parameter names and values are the... 
                          # ...earliest iteration when to start sampling them.  If set to...
                          # ...infinity, the param wont be fit.  Don't sample c_I.

model.fit(Beta_IJ, num_itns=num_itns, verbose=verbose, burnin=burnin, initialize=initialize)
# Out:
# INITIALIZING...
#
# 46.6571ms: sampling Lambda_2IJ
# 191.4799ms: sampling Y_2IJ
# 46.8001ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1230ms: sampling Theta_IC
# 3.6180ms: sampling Phi_JK
# 0.0122ms: sampling Pi_CK
# 0.0110ms: sampling c_I
# 3 95317
# ITERATION 1: sparsity: 0.046529, num_tokens: 95317
#
# 47.1561ms: sampling Lambda_2IJ
# 204.8161ms: sampling Y_2IJ
# 53.3061ms: sampling shp_2CK
# 0.0012ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1149ms: sampling Theta_IC
# 4.3259ms: sampling Phi_JK
# 0.0131ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 3 101344
# ITERATION 2: sparsity: 0.049328, num_tokens: 101344
#
# 54.2538ms: sampling Lambda_2IJ
# 198.7250ms: sampling Y_2IJ
# 53.2031ms: sampling shp_2CK
# 0.0021ms: sampling shp_IC
# 0.0000ms: sampling shp_JK
# 0.1171ms: sampling Theta_IC
# 4.8001ms: sampling Phi_JK
# 0.0129ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 3 101961
# ITERATION 3: sparsity: 0.049640, num_tokens: 101961
#
# 51.4178ms: sampling Lambda_2IJ
# 198.5321ms: sampling Y_2IJ
# 48.8429ms: sampling shp_2CK
# 0.0021ms: sampling shp_IC
# 0.0012ms: sampling shp_JK
# 0.1140ms: sampling Theta_IC
# 5.3461ms: sampling Phi_JK
# 0.0150ms: sampling Pi_CK
# 0.0091ms: sampling c_I
# 4 102864
# ITERATION 4: sparsity: 0.050027, num_tokens: 102864
#
# 53.6520ms: sampling Lambda_2IJ
# 188.8578ms: sampling Y_2IJ
# 51.5270ms: sampling shp_2CK
# 0.0021ms: sampling shp_IC
# 0.0000ms: sampling shp_JK
# 0.1168ms: sampling Theta_IC
# 5.2841ms: sampling Phi_JK
# 0.0122ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 4 104238
# ITERATION 5: sparsity: 0.050551, num_tokens: 104238
#
# 52.2361ms: sampling Lambda_2IJ
# 198.8490ms: sampling Y_2IJ
# 50.7259ms: sampling shp_2CK
# 0.0021ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1159ms: sampling Theta_IC
# 5.5449ms: sampling Phi_JK
# 0.0119ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 3 105771
# ITERATION 6: sparsity: 0.051324, num_tokens: 105771
#
# 54.8730ms: sampling Lambda_2IJ
# 198.1170ms: sampling Y_2IJ
# 52.3839ms: sampling shp_2CK
# 0.0021ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1240ms: sampling Theta_IC
# 5.9071ms: sampling Phi_JK
# 0.0150ms: sampling Pi_CK
# 0.0088ms: sampling c_I
# 4 106503
# ITERATION 7: sparsity: 0.051632, num_tokens: 106503
#
# 51.1751ms: sampling Lambda_2IJ
# 236.0308ms: sampling Y_2IJ
# 69.6890ms: sampling shp_2CK
# 0.0019ms: sampling shp_IC
# 0.0019ms: sampling shp_JK
# 0.1261ms: sampling Theta_IC
# 6.0928ms: sampling Phi_JK
# 0.0138ms: sampling Pi_CK
# 0.0119ms: sampling c_I
# 4 107819
# ITERATION 8: sparsity: 0.052156, num_tokens: 107819
#
# 54.4920ms: sampling Lambda_2IJ
# 203.4991ms: sampling Y_2IJ
# 58.0120ms: sampling shp_2CK
# 0.0029ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1152ms: sampling Theta_IC
# 5.5912ms: sampling Phi_JK
# 0.0138ms: sampling Pi_CK
# 0.0091ms: sampling c_I
# 3 108425
# ITERATION 9: sparsity: 0.052443, num_tokens: 108425
#
# 53.3051ms: sampling Lambda_2IJ
# 231.4708ms: sampling Y_2IJ
# 65.7752ms: sampling shp_2CK
# 0.0029ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1180ms: sampling Theta_IC
# 5.8548ms: sampling Phi_JK
# 0.0248ms: sampling Pi_CK
# 0.0200ms: sampling c_I
# 4 109760
# ITERATION 10: sparsity: 0.053011, num_tokens: 109760
#
# 56.9918ms: sampling Lambda_2IJ
# 462.0421ms: sampling Y_2IJ
# 323.3900ms: sampling shp_2CK
# 0.0021ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1230ms: sampling Theta_IC
# 5.5809ms: sampling Phi_JK
# 0.0131ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 7 789043
# ITERATION 11: sparsity: 0.311392, num_tokens: 789043
#
# 55.4278ms: sampling Lambda_2IJ
# 489.1460ms: sampling Y_2IJ
# 402.8261ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1180ms: sampling Theta_IC
# 5.3999ms: sampling Phi_JK
# 0.0119ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 8 975529
# ITERATION 12: sparsity: 0.364875, num_tokens: 975529
#
# 54.5290ms: sampling Lambda_2IJ
# 540.2870ms: sampling Y_2IJ
# 419.9550ms: sampling shp_2CK
# 0.0029ms: sampling shp_IC
# 0.0029ms: sampling shp_JK
# 0.1750ms: sampling Theta_IC
# 5.5060ms: sampling Phi_JK
# 0.0122ms: sampling Pi_CK
# 0.0110ms: sampling c_I
# 8 1030783
# ITERATION 13: sparsity: 0.378869, num_tokens: 1030783
#
# 49.3259ms: sampling Lambda_2IJ
# 507.4961ms: sampling Y_2IJ
# 445.9009ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0000ms: sampling shp_JK
# 0.1159ms: sampling Theta_IC
# 5.8391ms: sampling Phi_JK
# 0.0200ms: sampling Pi_CK
# 0.0191ms: sampling c_I
# 8 1048870
# ITERATION 14: sparsity: 0.382539, num_tokens: 1048870
#
# 51.5680ms: sampling Lambda_2IJ
# 503.1309ms: sampling Y_2IJ
# 424.0232ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1202ms: sampling Theta_IC
# 5.2488ms: sampling Phi_JK
# 0.0131ms: sampling Pi_CK
# 0.0081ms: sampling c_I
# 8 1052805
# ITERATION 15: sparsity: 0.383037, num_tokens: 1052805
#
# 47.5368ms: sampling Lambda_2IJ
# 481.3590ms: sampling Y_2IJ
# 391.2151ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1161ms: sampling Theta_IC
# 5.2650ms: sampling Phi_JK
# 0.0122ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 8 1055663
# ITERATION 16: sparsity: 0.382520, num_tokens: 1055663
#
# 48.4800ms: sampling Lambda_2IJ
# 503.5319ms: sampling Y_2IJ
# 434.3650ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1349ms: sampling Theta_IC
# 5.5802ms: sampling Phi_JK
# 0.0129ms: sampling Pi_CK
# 0.0160ms: sampling c_I
# 8 1059754
# ITERATION 17: sparsity: 0.382614, num_tokens: 1059754
#
# 49.7260ms: sampling Lambda_2IJ
# 527.7262ms: sampling Y_2IJ
# 428.1509ms: sampling shp_2CK
# 0.0021ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1190ms: sampling Theta_IC
# 5.2848ms: sampling Phi_JK
# 0.0122ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 7 1064816
# ITERATION 18: sparsity: 0.382922, num_tokens: 1064816
#
# 49.6991ms: sampling Lambda_2IJ
# 514.1928ms: sampling Y_2IJ
# 440.0630ms: sampling shp_2CK
# 0.0041ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1481ms: sampling Theta_IC
# 5.6891ms: sampling Phi_JK
# 0.0119ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 8 1067708
# ITERATION 19: sparsity: 0.382945, num_tokens: 1067708
#
# 50.4770ms: sampling Lambda_2IJ
# 525.7962ms: sampling Y_2IJ
# 432.6911ms: sampling shp_2CK
# 0.0021ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1161ms: sampling Theta_IC
# 5.3070ms: sampling Phi_JK
# 0.0122ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 8 1068593
# ITERATION 20: sparsity: 0.381841, num_tokens: 1068593
#
# 52.2590ms: sampling Lambda_2IJ
# 719.2621ms: sampling Y_2IJ
# 586.9279ms: sampling shp_2CK
# 0.0012ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1919ms: sampling Theta_IC
# 5.3020ms: sampling Phi_JK
# 0.0122ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 10 1702659
# ITERATION 21: sparsity: 0.509892, num_tokens: 1702659
#
# 50.1270ms: sampling Lambda_2IJ
# 787.2770ms: sampling Y_2IJ
# 645.6079ms: sampling shp_2CK
# 0.0019ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1161ms: sampling Theta_IC
# 5.2240ms: sampling Phi_JK
# 0.0129ms: sampling Pi_CK
# 0.0420ms: sampling c_I
# 11 1934331
# ITERATION 22: sparsity: 0.547481, num_tokens: 1934331
#
# 50.9470ms: sampling Lambda_2IJ
# 816.9219ms: sampling Y_2IJ
# 684.3638ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1159ms: sampling Theta_IC
# 5.2199ms: sampling Phi_JK
# 0.0131ms: sampling Pi_CK
# 0.0138ms: sampling c_I
# 10 2014500
# ITERATION 23: sparsity: 0.559651, num_tokens: 2014500
#
# 53.8340ms: sampling Lambda_2IJ
# 836.6461ms: sampling Y_2IJ
# 646.4119ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0000ms: sampling shp_JK
# 0.1180ms: sampling Theta_IC
# 5.4190ms: sampling Phi_JK
# 0.0119ms: sampling Pi_CK
# 0.0091ms: sampling c_I
# 12 2044362
# ITERATION 24: sparsity: 0.563296, num_tokens: 2044362
#
# 51.1880ms: sampling Lambda_2IJ
# 832.3829ms: sampling Y_2IJ
# 642.2808ms: sampling shp_2CK
# 0.0019ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1199ms: sampling Theta_IC
# 5.2211ms: sampling Phi_JK
# 0.0129ms: sampling Pi_CK
# 0.0122ms: sampling c_I
# 13 2057181
# ITERATION 25: sparsity: 0.564719, num_tokens: 2057181
#
# 45.6240ms: sampling Lambda_2IJ
# 798.9922ms: sampling Y_2IJ
# 666.8110ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1161ms: sampling Theta_IC
# 5.5189ms: sampling Phi_JK
# 0.0138ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 12 2065505
# ITERATION 26: sparsity: 0.564557, num_tokens: 2065505
#
# 51.6801ms: sampling Lambda_2IJ
# 814.2948ms: sampling Y_2IJ
# 669.7271ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1190ms: sampling Theta_IC
# 5.3380ms: sampling Phi_JK
# 0.0141ms: sampling Pi_CK
# 0.0091ms: sampling c_I
# 11 2069198
# ITERATION 27: sparsity: 0.564839, num_tokens: 2069198
#
# 50.5569ms: sampling Lambda_2IJ
# 842.5260ms: sampling Y_2IJ
# 663.9960ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1190ms: sampling Theta_IC
# 5.2519ms: sampling Phi_JK
# 0.0131ms: sampling Pi_CK
# 0.0088ms: sampling c_I
# 11 2073461
# ITERATION 28: sparsity: 0.564994, num_tokens: 2073461
#
# 47.8721ms: sampling Lambda_2IJ
# 820.5261ms: sampling Y_2IJ
# 640.4850ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1159ms: sampling Theta_IC
# 5.2481ms: sampling Phi_JK
# 0.0131ms: sampling Pi_CK
# 0.0098ms: sampling c_I
# 11 2077897
# ITERATION 29: sparsity: 0.564326, num_tokens: 2077897
#
# 43.5598ms: sampling Lambda_2IJ
# 838.1898ms: sampling Y_2IJ
# 788.8501ms: sampling shp_2CK
# 0.0060ms: sampling shp_IC
# 0.0031ms: sampling shp_JK
# 0.1321ms: sampling Theta_IC
# 5.7940ms: sampling Phi_JK
# 0.0131ms: sampling Pi_CK
# 0.0238ms: sampling c_I
# 11 2079198
# ITERATION 30: sparsity: 0.564401, num_tokens: 2079198
#
# 46.5798ms: sampling Lambda_2IJ
# 2151.6111ms: sampling Y_2IJ
# 1744.3998ms: sampling shp_2CK
# 0.0012ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1199ms: sampling Theta_IC
# 6.6519ms: sampling Phi_JK
# 0.0222ms: sampling Pi_CK
# 0.0091ms: sampling c_I
# 33 9538738
# ITERATION 31: sparsity: 0.876660, num_tokens: 9538738
#
# 46.8121ms: sampling Lambda_2IJ
# 2551.1539ms: sampling Y_2IJ
# 1836.3619ms: sampling shp_2CK
# 0.0021ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1709ms: sampling Theta_IC
# 6.9921ms: sampling Phi_JK
# 0.0181ms: sampling Pi_CK
# 0.0179ms: sampling c_I
# 42 16801763
# ITERATION 32: sparsity: 0.938190, num_tokens: 16801763
#
# 51.0459ms: sampling Lambda_2IJ
# 2692.4632ms: sampling Y_2IJ
# 2049.6230ms: sampling shp_2CK
# 0.0031ms: sampling shp_IC
# 0.0012ms: sampling shp_JK
# 0.1211ms: sampling Theta_IC
# 4.8771ms: sampling Phi_JK
# 0.0112ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 48 21865809
# ITERATION 33: sparsity: 0.958202, num_tokens: 21865809
#
# 46.2611ms: sampling Lambda_2IJ
# 2807.4050ms: sampling Y_2IJ
# 2189.1961ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1180ms: sampling Theta_IC
# 4.9689ms: sampling Phi_JK
# 0.0141ms: sampling Pi_CK
# 0.0098ms: sampling c_I
# 50 24857225
# ITERATION 34: sparsity: 0.966889, num_tokens: 24857225
#
# 59.2470ms: sampling Lambda_2IJ
# 2890.6081ms: sampling Y_2IJ
# 2241.5819ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0012ms: sampling shp_JK
# 0.1171ms: sampling Theta_IC
# 4.7660ms: sampling Phi_JK
# 0.0110ms: sampling Pi_CK
# 0.0110ms: sampling c_I
# 57 26491912
# ITERATION 35: sparsity: 0.971319, num_tokens: 26491912
#
# 45.6221ms: sampling Lambda_2IJ
# 2965.8141ms: sampling Y_2IJ
# 2275.6948ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0000ms: sampling shp_JK
# 0.1159ms: sampling Theta_IC
# 4.7421ms: sampling Phi_JK
# 0.0112ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 54 27356265
# ITERATION 36: sparsity: 0.973774, num_tokens: 27356265
#
# 45.6109ms: sampling Lambda_2IJ
# 2968.0810ms: sampling Y_2IJ
# 2297.0910ms: sampling shp_2CK
# 0.0012ms: sampling shp_IC
# 0.0031ms: sampling shp_JK
# 0.1149ms: sampling Theta_IC
# 4.7631ms: sampling Phi_JK
# 0.0110ms: sampling Pi_CK
# 0.0210ms: sampling c_I
# 54 27803477
# ITERATION 37: sparsity: 0.975553, num_tokens: 27803477
#
# 46.7570ms: sampling Lambda_2IJ
# 2992.0239ms: sampling Y_2IJ
# 2359.9751ms: sampling shp_2CK
# 0.0019ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1240ms: sampling Theta_IC
# 4.7302ms: sampling Phi_JK
# 0.0112ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 53 28051904
# ITERATION 38: sparsity: 0.976688, num_tokens: 28051904
#
# 46.3181ms: sampling Lambda_2IJ
# 2984.0028ms: sampling Y_2IJ
# 2565.2041ms: sampling shp_2CK
# 0.0021ms: sampling shp_IC
# 0.0029ms: sampling shp_JK
# 0.1829ms: sampling Theta_IC
# 5.5711ms: sampling Phi_JK
# 0.0122ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 54 28194442
# ITERATION 39: sparsity: 0.977693, num_tokens: 28194442
#
# 46.5932ms: sampling Lambda_2IJ
# 3212.6050ms: sampling Y_2IJ
# 2659.3862ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1221ms: sampling Theta_IC
# 4.7419ms: sampling Phi_JK
# 0.0119ms: sampling Pi_CK
# 0.0100ms: sampling c_I
# 57 28281712
# ITERATION 40: sparsity: 0.978414, num_tokens: 28281712
#
#
# STARTING INFERENCE...
#
# 44.9412ms: sampling Lambda_2IJ
# 3015.0869ms: sampling Y_2IJ
# 2444.8409ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0000ms: sampling shp_JK
# 0.1199ms: sampling Theta_IC
# 4.7832ms: sampling Phi_JK
# 0.0160ms: sampling Pi_CK
# 56 28333093
# ITERATION 1: sparsity: 0.979038, num_tokens: 28333093
#
# 48.9199ms: sampling Lambda_2IJ
# 2960.3221ms: sampling Y_2IJ
# 2466.5160ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1199ms: sampling Theta_IC
# 4.6952ms: sampling Phi_JK
# 0.0112ms: sampling Pi_CK
# 56 28373674
# ITERATION 2: sparsity: 0.979480, num_tokens: 28373674
#
# 45.2640ms: sampling Lambda_2IJ
# 2985.6582ms: sampling Y_2IJ
# 2456.6519ms: sampling shp_2CK
# 0.0029ms: sampling shp_IC
# 0.0050ms: sampling shp_JK
# 0.1519ms: sampling Theta_IC
# 5.0569ms: sampling Phi_JK
# 0.0200ms: sampling Pi_CK
# 54 28405736
# ITERATION 3: sparsity: 0.979722, num_tokens: 28405736
#
# 51.2800ms: sampling Lambda_2IJ
# 2983.9580ms: sampling Y_2IJ
# 2421.7842ms: sampling shp_2CK
# 0.0041ms: sampling shp_IC
# 0.0021ms: sampling shp_JK
# 0.1659ms: sampling Theta_IC
# 5.7819ms: sampling Phi_JK
# 0.0131ms: sampling Pi_CK
# 67 28420751
# ITERATION 4: sparsity: 0.980060, num_tokens: 28420751
#
# 50.4620ms: sampling Lambda_2IJ
# 3116.0190ms: sampling Y_2IJ
# 2500.2310ms: sampling shp_2CK
# 0.0019ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1199ms: sampling Theta_IC
# 5.6450ms: sampling Phi_JK
# 0.0279ms: sampling Pi_CK
# 57 28448859
# ITERATION 5: sparsity: 0.980301, num_tokens: 28448859
#
# 61.1632ms: sampling Lambda_2IJ
# 3031.7528ms: sampling Y_2IJ
# 2571.3310ms: sampling shp_2CK
# 0.0019ms: sampling shp_IC
# 0.0012ms: sampling shp_JK
# 0.1180ms: sampling Theta_IC
# 4.7622ms: sampling Phi_JK
# 0.0119ms: sampling Pi_CK
# 58 28463319
# ITERATION 6: sparsity: 0.980533, num_tokens: 28463319
#
# 46.1061ms: sampling Lambda_2IJ
# 2981.7531ms: sampling Y_2IJ
# 2770.4592ms: sampling shp_2CK
# 0.0019ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1099ms: sampling Theta_IC
# 5.6052ms: sampling Phi_JK
# 0.0119ms: sampling Pi_CK
# 55 28471258
# ITERATION 7: sparsity: 0.980603, num_tokens: 28471258
#
# 53.9751ms: sampling Lambda_2IJ
# 3054.0280ms: sampling Y_2IJ
# 2569.9770ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1168ms: sampling Theta_IC
# 5.9409ms: sampling Phi_JK
# 0.0141ms: sampling Pi_CK
# 54 28489071
# ITERATION 8: sparsity: 0.980662, num_tokens: 28489071
#
# 46.2670ms: sampling Lambda_2IJ
# 3017.8940ms: sampling Y_2IJ
# 2353.8029ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1051ms: sampling Theta_IC
# 4.7109ms: sampling Phi_JK
# 0.0119ms: sampling Pi_CK
# 56 28501556
# ITERATION 9: sparsity: 0.980887, num_tokens: 28501556
#
# 45.2201ms: sampling Lambda_2IJ
# 2951.6580ms: sampling Y_2IJ
# 2443.1689ms: sampling shp_2CK
# 0.0010ms: sampling shp_IC
# 0.0010ms: sampling shp_JK
# 0.1061ms: sampling Theta_IC
# 5.5110ms: sampling Phi_JK
# 0.0181ms: sampling Pi_CK
# 54 28503931
# ITERATION 10: sparsity: 0.980847, num_tokens: 28503931

# %%
state = model.get_state()
Pi_CK = state['Pi_CK']        # CxK core matrix
Theta_IC = state['Theta_IC']  # IxC sample-cluster factor matrix
Phi_JK = state['Phi_JK']      # JxK loci-cluster factor matrix
Y_2IJ = state['Y_2IJ']        # 2xIxJ latent Poisson counts
                              # Y_2IJ[0] are the methylated counts
                              # Y_2IJ[1] are the unmethylated counts
